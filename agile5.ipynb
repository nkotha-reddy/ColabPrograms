# %% [markdown]
# <a href="https://colab.research.google.com/github/nkotha-reddy/ColabPrograms/blob/main/agile5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(x,a,b,c):
  return a*x**2+b*x+c
def generate_weather_data(start,end,num_points,a,b,c,noise_factor=10):
  x = np.linspace(start,end,num_points)
  y = quadratic_model(x,a,b,c)+np.random.normal(0,noise_factor,num_points)
  return x,y
def plot_weather_data(x,y,title):
  plt.scatter(x,y,label='weather data')
  plt.title(title)
  plt.xlabel('time')
  plt.ylabel('temperature')
  plt.legend()
  plt.show()

a_initial=0.5
b_initial=-5
c_initial=20

start_time=0
end_time=10
num_points=100

a_agile = a_initial
b_agile = b_initial
c_agile = c_initial

x_data,y_agile=generate_weather_data(start_time,end_time,num_points,a_agile,b_agile,c_agile)

plot_weather_data(x_data,y_agile,'agile model:initial Weather Data')
num_sprints=3
for sprint in range(1,num_sprints+1):
  print(f"\nsprint{sprint}:gather feedback and refine the model")
  a_agile+=float(input("enter the updated value of a:"))
  b_agile+=float(input("enter the updated value of b:"))
  c_agile+=float(input("enter the updated value of c:"))

  y_agile=quadratic_model(x_data,a_agile,b_agile,c_agile)

  plot_weather_data(x_data,y_agile,f'agile model:sprint{sprint} Weather Data')

final_temperature=y_agile[-1]

print(f"\nfinal temperature for agile model:{final_temperature}")
# Out:
# sprint1:gather feedback and refine the model
# enter the updated value of a:2
# enter the updated value of b:4
# enter the updated value of c:5
# sprint2:gather feedback and refine the model
# enter the updated value of a:4
# enter the updated value of b:7
# enter the updated value of c:8
# sprint3:gather feedback and refine the model
